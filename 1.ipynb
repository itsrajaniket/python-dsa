# %% [markdown]
# ### 1 Write a Python program to do arithmetical operations add

# %%
num1 =int(input("Enter first number  :"))
num2 = int(input("Enter second number : "))

sum = num1 + num2 

print(f"Sum of {num1} and {num2} = {sum} ")

# %% [markdown]
# ### 2 Write a Python program to do arithmetical operations division.

# %%
num1 = int(input("enter first number :"))
num2 = int(input("enter second number :"))
if num2 == 0 :
    print ("number cant be 0")
else :
    result = num1 / num2
    print(f"division of {num1} and {num2} = {result} ")

# %% [markdown]
# ### 3 Write a Python program to find the area of a triangle

# %%
base = int(input("Enter the base of the triangle: "))
height = int(input("Enter the height of the triangle: "))

area = (base * height) / 2
print(f"Area of triangle = {area}")

# %% [markdown]
# ### 4 Write a Python program to swap two variables

# %%
num1 =int(input("Enter first number - A:"))
num2 = int(input("Enter second number - B: "))
print(f"Original values: A = {num1}, B = {num2}")
num1 = num1 + num2
num2 = num1 - num2
num1 = num1 - num2

print(f"Swapped values: A={num1} and B={num2}")

# %% [markdown]
# ### 5 Write a Python program to generate a random number.

# %%
import time
num = int(time.time()*10000000%10000)
print(f"Random number is = {num}")

# %% [markdown]
# ### 6 Write a Python program to convert kilometers to miles.

# %%
km = int(input("enter the km" ))
#  Conversion factor: 1 kilometer = 0.621371 miles
m = km * 0.621371
print(f"{km} kilometers will be = {m: .2f} miles")

# %% [markdown]
# ### Program 7
# #### Write a Python program to convert Celsius to Fahrenheit.
# - Conversion formula: Fahrenheit = (Celsius * 9/5) + 32

# %%
c = int(input("Enter the celsius:"))
f = (c*9/5) + 32
print(f"{c} Celsius will be = {f} Fahrenheit")

# %% [markdown]
# ### Program 8
# ### Write a Python Program to Check if a Number is Positive, Negative or Zero.

# %%
num = int(input("enter your number :"))
if (num < 0):
    print(f"the number u enter {num} is a negative number")
elif(num == 0):
    print(f"the number u enter {num} is a zero number")
elif ( num >0):
    print(f"the number u enter {num} is a positive number")
else:
    print("enter valid number ")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 num = int(input("enter your number :"))
#       2 if (num < 0):
#       3     print(f"the number u enter {num} is a negative number")
#       4 elif(num == 0):
#
# ValueError: invalid literal for int() with base 10: 'a'
